# %%
#Import dependencies 
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
load_school_data = "../Resources/schools_complete.csv"
load_student_data = "../Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(load_school_data)
student_data = pd.read_csv(load_student_data)

# Combine the data into a single dataset.  
complete_school_data = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
complete_school_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
##DISTRICT SUMMARY

#Calculate the total number of schools
number_of_schools = complete_school_data["school_name"].nunique()
number_of_schools

#Calculate the total number of students
number_of_students = complete_school_data["student_name"].count()
number_of_students

#Calculate the total budget
school_budgets = complete_school_data["budget"].unique()
total_budget = school_budgets.sum()
total_budget

#Calculate the average math score
av_math = complete_school_data["math_score"].mean()
av_math

#Calculate the average reading score
av_reading = complete_school_data["reading_score"].mean()
av_reading

#Calculate the percentage of students with a passing math score (70 or greater)
math_pass = complete_school_data.loc[complete_school_data["math_score"] >=70, "student_name"]
total_math_pass = ((math_pass.count())/(number_of_students))
total_math_pass

#Calculate the percentage of students with a passing reading score (70 or greater)
reading_pass = complete_school_data.loc[complete_school_data["reading_score"] >=70, "student_name"]
total_reading_pass = ((reading_pass.count())/(number_of_students))
total_reading_pass

#Calculate the percentage of students who passed math and reading (% Overall Passing)
both_pass = complete_school_data.loc[(complete_school_data["math_score"] >=70) & (complete_school_data["reading_score"] >=70), "student_name"]
percent_both_pass = ((both_pass.count())/(number_of_students))
percent_both_pass

#Create a dataframe to hold the above results
summary_df = pd.DataFrame({"Total Schools": [number_of_schools],
                              "Total Students": number_of_students,
                              "Total Budget": total_budget,
                              "Average Math Score": av_math,
                              "Average Reading Score": av_reading, 
                              "% Passing Math" : total_math_pass, 
                              "% Passing Reading" : total_reading_pass, 
                              "% Overall Passing": percent_both_pass})

#Optional: give the displayed data cleaner formatting
summary_df.style.format({"Total Students" : "{0:,}",
                         "Total Budget" : "${0:,.2f}",
                         "Average Math Score" : "{:.3f}",
                         "Average Reading Score" : "{:.3f}",
                         "% Passing Math": "{:.2%}", 
                         "% Passing Reading": "{:.2%}", 
                         "% Overall Passing": "{:.2%}" })
# Out:
# <style  type="text/css" >
# </style><table id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col0" class="data row0 col0" >15</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col1" class="data row0 col1" >39,170</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col2" class="data row0 col2" >$24,649,428.00</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col3" class="data row0 col3" >78.985</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col4" class="data row0 col4" >81.878</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col5" class="data row0 col5" >74.98%</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col6" class="data row0 col6" >85.81%</td>
#                         <td id="T_fb1bd1e8_6004_11eb_b1b3_acde48001122row0_col7" class="data row0 col7" >65.17%</td>
#             </tr>
#     </tbody></table>

# %%
#SCHOOL SUMMARY 
#Create an overview table that summarizes key metrics about each school, including:

# School Name
schools_grouped = complete_school_data.groupby("school_name")

# School Type
types_byschool = complete_school_data["type"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c6dcf483e53e> in <module>
#       4 # School Name
#       5 #schools_grouped = complete_school_data.groupby("school_name")
# ----> 6 pd.cut(complete_school_data["school_name"], bins, labels=group_labels).head()
#       7
#       8 # School Type
#
# NameError: name 'bins' is not defined

# %%
# Total Students
student_byschool = schools_grouped["student_name"].count()

# Total School Budget
budget_byschool = schools_grouped.sort_values("budget")
budget_byschool

#Per Student Budget
#per_student = complete_school_data['budget']/complete_school_data['size']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f3f40e7ab521> in <module>
#       3
#       4 # Total School Budget
# ----> 5 budget_byschool = schools_grouped.sort_values("budget")
#       6 budget_byschool
#       7
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
# Average Math Score
av_math_byschool = schools_grouped["math_score"].mean()

# Average Reading Score
av_reading_byschool = schools_grouped["reading_score"].mean()

                                 "Total Budget": budget_byschool,
                                 "Average Math Score": av_math_byschool,
                                 "Average Reading Score": av_reading_byschool,
                                 "% Passing Math" : percent_pass_math_byschool,
                                 "% Passing Reading" : percent_pass_reading_byschool,
                                 "% Overall Passing": overall_pass_rate_byschool})

#Rearrange the order
summary_byschool_ordered = summary_byschool [["School Type", 
                                   "Total Students", 
                                   "Total School Budget",
                                   "Per Student Budget",
                                   "Average Math Score",
                                   "Average Reading Score",
                                   "% Passing Math",
                                   "% Passing Reading",
                                   "% Overall Passing"]]

summary_byschool_ordered
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1121960d1f98> in <module>
#      18                                    "% Passing Math",
#      19                                    "% Passing Reading",
# ---> 20                                    "% Overall Passing"]]
#      21
#      22 summary_byschool_ordered
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['Per Student Budget', 'Total School Budget'] not in index"

# %%
#EXTRA CODE

#pd.cut(complete_school_data["school_name"], bins, labels=group_labels).head()

#type(student_byschool)

#student_byschool = school_data.set_index("school_name")["size"]

#df['DataFrame Column'] = df['DataFrame Column'].astype(float)

#schools_sorted = complete_school_data.sort_values("school_name")
#schools_sorted.head()

#schools_grouped.count().head()

# Reorganize and rename columns
#organized_df = complete_school_data[["type", "size", "student_name", "" ]]
#renamed_df = complete_school_data.rename(columns={"type":"School Type", "size":"Total Students", "budget":"Total School Budget"})


#renamed_df = complete_school_data.rename(columns={"type":"School Type", "size":"Total Students", "budget":"Total School Budget"})
#renamed_df

#renamed_df = complete_school_data.rename(columns={"type":"School Type", "size":"Total Students", "budget":"Total School Budget"})
#renamed_df

#float(total_math_pass)
#math_pass_byschool = schools_grouped.apply(total_math_pass)
#math_pass_byschool.head()

# %%
# Create a dataframe to hold the above results
summary_byschool = pd.DataFrame({"School Type" : types_byschool,
                                 "Total Students" : student_byschool, 
                                 "Total School Budget" : budget_byschool, 
                                 "Per Student Budget" : per_student, 
                                 "Average Math Score" : av_math_byschool, 
                                 "Average Reading Score" : av_reading_byschool, 
                                 "% Passing Math": percent_pass_math_byschool, 
                                 "% Passing Reading" : percent_pass_reading_byschool, 
                                 "Overall Passing Rate" : overall_pass_rate_byschool})



# #rearrange the order
# summary_byschool = school_summary [["School Type", 
#                                    "Total Students", 
#                                    "Total School Budget",
#                                    "Per Student Budget",
#                                    "Average Math Score",
#                                    "Average Reading Score",
#                                    "% Passing Math",
#                                    "% Passing Reading",
#                                    "Overall Passing Rate"
#                                    ]]
